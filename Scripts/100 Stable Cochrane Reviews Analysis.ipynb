# %% [markdown]
# # Statistical Analysis for errors in 100 Stable Cochrane Reviews

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("100_Stable_Reviews_Yogeshwar.xlsx", encoding = "latin1")

# %%
df.head()
# Out:
#              Study ID      Study Name  \
# 0      STD-Acuna-1981      Acuna 1981
# 1  STD-Benhamou-1991a  Benhamou 1991a
# 2  STD-Benhamou-1991a  Benhamou 1991a
# 3   STD-Brincker-1978   Brincker 1978
# 4   STD-Brincker-1983   Brincker 1983
#
#                                                Title Alternative Title  \
# 0  Ketoconazole prophylaxis of fungal infections ...              None
# 1  Does ketoconazole prevent fungal infection in ...              None
# 2  Results of a randomized double-blind placebo c...              None
# 3  Prophylactic treatment with miconazole in pati...              None
# 4  Prevention of mycosis in granulocytopenic pati...              None
#
#                                              Authors             Type  \
# 0                      Acuna G, Winston DJ, Young LS  CONFERENCE_PROC
# 1  Benhamou E, Hartmann O, Nogues C, Maraninchi D...  JOURNAL_ARTICLE
# 2  Hartmann O, Benhamou E, Maraninchi D, Valteau ...  JOURNAL_ARTICLE
# 3                                         Brincker H  JOURNAL_ARTICLE
# 4                                         Brincker H  JOURNAL_ARTICLE
#
#   Reference ID                ID Matched  Reference ID Type  \
# 0      3405716  NOT_FOUND;INVALID_JOURNAL             OTHER
# 1      3405718                    2049556             OTHER
# 2      3405719                  NOT_FOUND             OTHER
# 3      3405721                     356523             OTHER
# 4      3405723                    6308441             OTHER
#
#   Reference ID Other Type                                  Published Journal  \
# 0                  CRSREF  Program and Abstracts of 22nd Interscience Con...
# 1                  CRSREF                             Bone Marrow Transplant
# 2                  CRSREF                             Bone Marrow Transplant
# 3                  CRSREF                           Acta Medica Scandinavica
# 4                  CRSREF                                            Mykosen
#
#    Year     Volume          Page  \
# 0  1981       None  abstract 852
# 1  1991          7        127-31
# 2  1990  5 Suppl 2            19
# 3  1978        204         123-8
# 4  1983         26         242-7
#
#                                      Cochrane Review
# 0  CD000026 v. 16.0 Routine versus selective anti...
# 1  CD000026 v. 16.0 Routine versus selective anti...
# 2  CD000026 v. 16.0 Routine versus selective anti...
# 3  CD000026 v. 16.0 Routine versus selective anti...
# 4  CD000026 v. 16.0 Routine versus selective anti...

# %% [markdown]
# ### Number of articles in 100 reviews
# There are 1695 articles and each article has 15 attributes as meta data. Out of which , 1099 articles are matched.

# %%
df.shape
# Out:
# (1695, 15)

# %%
# Separting the matched articles
temp = []
for i in df['ID Matched ']:
    if type(i) == int:
        temp.append(i)

# %%
len(temp)
# Out:
# 1099

# %%
rct_matched = pd.read_csv("rct_scores.csv")

# %%
rct_matched.columns = ['ID Matched ', 'year', 'citation-only', 'citation-plus-mesh']

# %%
rct_matched.head()
# Out:
#    ID Matched   year  citation-only  citation-plus-mesh
# 0      2049556  1991        0.99736             0.99760
# 1       356523  1978        0.93830             0.73096
# 2      1965007  1990        0.95086             0.98848
# 3      2658574  1989        0.99937             0.99836
# 4      6087753  1984        0.39503             0.44073

# %%
rct_matched[rct_matched['citation-plus-mesh'] > 0.01]
# Out:
#       ID Matched   year  citation-only  citation-plus-mesh
# 0         2049556  1991        0.99736             0.99760
# 1          356523  1978        0.93830             0.73096
# 2         1965007  1990        0.95086             0.98848
# 3         2658574  1989        0.99937             0.99836
# 4         6087753  1984        0.39503             0.44073
# 5         7933535  1994        0.56619             0.58298
# 6         7703926  1994        0.56669             0.52547
# 7         8131635  1994        0.98894             0.99359
# 8         8182012  1994        0.98684             0.99082
# 9         1542320  1992        0.99966             0.99979
# 10        3548626  1987        0.99277             0.99395
# 11        6304203  1983        0.84297             0.63878
# 12       12673406  2003        0.16233             0.24490
# 13       10197802  1999        0.82787             0.98551
# 14        9669812  1998        0.99285             0.99348
# 15       10064240  1999        0.99979             0.99963
# 16       10671332  2000        0.99867             0.99900
# 17        1588260  1992        0.99204             0.98853
# 18       16766594  2006        0.99298             0.99324
# 19        1569339  1992        0.41284             0.31019
# 20        7985709  1994        0.98765             0.99218
# 21       11102422  2000        0.98762             0.96391
# 22       10064252  1999        0.99654             0.99872
# 23        7561177  1995        0.19632             0.38876
# 24       10979947  2000        0.98598             0.99420
# 25        7769290  1995        0.99741             0.99805
# 26       17580253  2007        0.99111             0.98864
# 27        7411865  1980        0.26746             0.30296
# 28        8136741  1993        0.99724             0.99702
# 29        8124207  1993        0.98967             0.99687
# ...           ...   ...            ...                 ...
# 972       6293073  1982        0.71449             0.78064
# 973       1503915  1992        0.98713             0.98080
# 974       8318411  1993        0.48253             0.46072
# 975       1098764  1975        0.59267             0.56579
# 976        324570  1977        0.60262             0.68043
# 977        367510  1978        0.07450             0.06167
# 978        444406  1979        0.77509             0.70487
# 979       3513684  1986        0.80906             0.59113
# 980       2920133  1989        0.53758             0.31816
# 981       3986070  1985        0.99376             0.99545
# 982       8471588  1993        0.99114             0.99292
# 983       7672875  1994        0.99518             0.99620
# 984       3287907  1988        0.92942             0.56045
# 985       3287907  1988        0.92942             0.56045
# 986      17692717  2007        0.99884             0.99888
# 987      15333415  2004        0.99870             0.99931
# 988      15200753  2004        0.99847             0.99912
# 989      12036167  2002        0.99180             0.99653
# 990      12638399  2003        0.99854             0.99906
# 991      15502051  2004        0.79879             0.91418
# 992       9220215  1997        0.49571             0.78103
# 993      15220020  2004        0.99682             0.99642
# 994      15922815  2005        0.99998             0.99997
# 995      15881486  2005        0.99598             0.99729
# 996      16855076  2006        0.68493             0.99245
# 997      10868557  2000        0.99605             0.99790
# 998      15763605  2005        0.99871             0.99890
# 999       8222498  1993        0.99322             0.99415
# 1000      8844441  1996        0.99254             0.99477
# 1001     15823764  2004        0.99744             0.99647
#
# [947 rows x 4 columns]

# %%
rct_matched.shape
# Out:
# (1002, 4)

# %%
rct_matched['ID Matched ']
# Out:
# 0        2049556
# 1         356523
# 2        1965007
# 3        2658574
# 4        6087753
# 5        7933535
# 6        7703926
# 7        8131635
# 8        8182012
# 9        1542320
# 10       3548626
# 11       6304203
# 12      12673406
# 13      10197802
# 14       9669812
# 15      10064240
# 16      10671332
# 17       1588260
# 18      16766594
# 19       1569339
# 20       7985709
# 21      11102422
# 22      10064252
# 23       7561177
# 24      10979947
# 25       7769290
# 26      17580253
# 27       7411865
# 28       8136741
# 29       8124207
#           ...
# 972      6293073
# 973      1503915
# 974      8318411
# 975      1098764
# 976       324570
# 977       367510
# 978       444406
# 979      3513684
# 980      2920133
# 981      3986070
# 982      8471588
# 983      7672875
# 984      3287907
# 985      3287907
# 986     17692717
# 987     15333415
# 988     15200753
# 989     12036167
# 990     12638399
# 991     15502051
# 992      9220215
# 993     15220020
# 994     15922815
# 995     15881486
# 996     16855076
# 997     10868557
# 998     15763605
# 999      8222498
# 1000     8844441
# 1001    15823764
# Name: ID Matched , Length: 1002, dtype: int64

# %%
matched_df = df[df['ID Matched '].isin(rct_matched['ID Matched '])]

# %%
not_matched = list(set(temp) - set(rct_matched['ID Matched ']))

# %%
len(not_matched)
# Out:
# 76

# %%
unmatched_df = df[df['ID Matched '].isin(not_matched)]

# %%
matched_df.head()
# Out:
#              Study ID      Study Name  \
# 1  STD-Benhamou-1991a  Benhamou 1991a
# 3   STD-Brincker-1978   Brincker 1978
# 5    STD-Caselli-1990    Caselli 1990
# 6      STD-EORTC-1989      EORTC 1989
# 7      STD-Estey-1984      Estey 1984
#
#                                                Title Alternative Title  \
# 1  Does ketoconazole prevent fungal infection in ...              None
# 3  Prophylactic treatment with miconazole in pati...              None
# 5  Antifungal chemoprophylaxis in cancer children...              None
# 6  Empiric antifungal therapy in febrile granuloc...              None
# 7  Infection prophylaxis in acute leukemia. Compa...              None
#
#                                              Authors             Type  \
# 1  Benhamou E, Hartmann O, Nogues C, Maraninchi D...  JOURNAL_ARTICLE
# 3                                         Brincker H  JOURNAL_ARTICLE
# 5  Caselli D, Arico M, Michelone G, Cavanna C, Ne...  JOURNAL_ARTICLE
# 6  EORTC International Antimicrobial Therapy Coop...  JOURNAL_ARTICLE
# 7  Estey E, Maksymiuk A, Smith T, Fainstein V, Ke...  JOURNAL_ARTICLE
#
#   Reference ID ID Matched  Reference ID Type Reference ID Other Type  \
# 1      3405718     2049556             OTHER                  CRSREF
# 3      3405721      356523             OTHER                  CRSREF
# 5      3405725     1965007             OTHER                  CRSREF
# 6      3405727     2658574             OTHER                  CRSREF
# 7      3405729     6087753             OTHER                  CRSREF
#
#                   Published Journal  Year Volume    Page  \
# 1            Bone Marrow Transplant  1991      7  127-31
# 3          Acta Medica Scandinavica  1978    204   123-8
# 5                    Microbiologica  1990     13  347-51
# 6  The American Journal of Medicine  1989     86  668-72
# 7     Archives of Internal Medicine  1984    144  1562-8
#
#                                      Cochrane Review
# 1  CD000026 v. 16.0 Routine versus selective anti...
# 3  CD000026 v. 16.0 Routine versus selective anti...
# 5  CD000026 v. 16.0 Routine versus selective anti...
# 6  CD000026 v. 16.0 Routine versus selective anti...
# 7  CD000026 v. 16.0 Routine versus selective anti...

# %%
unmatched_df.head()
# Out:
#                              Study ID         Study Name  \
# 4                   STD-Brincker-1983      Brincker 1983
# 32                     STD-Pizzo-1982         Pizzo 1982
# 45                  STD-Tollemar-1993      Tollemar 1993
# 47                  STD-Tollemar-1993      Tollemar 1993
# 67  STD-Dabis-AN_x002c_-IP_x002c_-PNm  Dabis AN, IP, PNm
#
#                                                 Title Alternative Title  \
# 4   Prevention of mycosis in granulocytopenic pati...              None
# 32  Empiric antibiotic and antifungal therapy for ...              None
# 45  Fungal prophylaxis with AmBisome in liver and ...              None
# 47  Prophylactic use of liposomal amphotericin B (...              None
# 67  Prevention of mother-to-child transmission of ...              None
#
#                                               Authors             Type  \
# 4                                          Brincker H  JOURNAL_ARTICLE
# 32       Pizzo PA, Robichaud KJ, Gill FA, Witebsky FG  JOURNAL_ARTICLE
# 45  Tollemar J, Hockerstedt K, Ericzon BG, Sundber...  JOURNAL_ARTICLE
# 47  Tollemar J, Ringden O, Andersson S, Sundberg B...  JOURNAL_ARTICLE
# 67                  Msellati P, Ramon R, Viho I et al  JOURNAL_ARTICLE
#
#    Reference ID ID Matched  Reference ID Type Reference ID Other Type  \
# 4       3405723     6308441             OTHER                  CRSREF
# 32      3405768     7058815             OTHER                  CRSREF
# 45      3405788     8030161             OTHER                  CRSREF
# 47      3405790     8442163             OTHER                  CRSREF
# 67         None     9677183              None                    None
#
#                    Published Journal  Year Volume    Page  \
# 4                            Mykosen  1983     26   242-7
# 32  The American Journal of Medicine  1982     72  101-11
# 45       Transplantation Proceedings  1994     26    1833
# 47       Transplantation Proceedings  1993     25  1495-7
# 67                              AIDS  1998     12  1257-8
#
#                                       Cochrane Review
# 4   CD000026 v. 16.0 Routine versus selective anti...
# 32  CD000026 v. 16.0 Routine versus selective anti...
# 45  CD000026 v. 16.0 Routine versus selective anti...
# 47  CD000026 v. 16.0 Routine versus selective anti...
# 67  CD000102 v. 12.0 Interventions for reducing th...

# %%
matched_df.shape
# Out:
# (1002, 15)

# %%
unmatched_df.shape
# Out:
# (97, 15)

# %%
unmatched_df['ID Matched '].value_counts()
# Out:
# 4867932     5
# 4873222     5
# 13969123    5
# 5643387     5
# 9708404     4
# 8977514     2
# 9525400     2
# 2936373     1
# 15138641    1
# 4616883     1
# 13884081    1
# 1191165     1
# 10224440    1
# 7454128     1
# 17656293    1
# 2220844     1
# 4892340     1
# 13907771    1
# 14575938    1
# 8067290     1
# 14045220    1
# 9677183     1
# 4891424     1
# 727035      1
# 5477261     1
# 2490035     1
# 14575944    1
# 10235147    1
# 7988613     1
# 8009608     1
#            ..
# 21090384    1
# 5338474     1
# 7084265     1
# 8442163     1
# 4158171     1
# 10402419    1
# 9729145     1
# 812666      1
# 4861208     1
# 14476668    1
# 4681896     1
# 3254707     1
# 4189785     1
# 4100347     1
# 4809808     1
# 14226395    1
# 8656837     1
# 16682694    1
# 4314823     1
# 376136      1
# 14575941    1
# 8030161     1
# 13892318    1
# 4177491     1
# 3904340     1
# 7058815     1
# 6308441     1
# 2197628     1
# 801115      1
# 5845249     1
# Name: ID Matched , Length: 76, dtype: int64

# %%
rct_matched['ID Matched '].tolist() == matched_df['ID Matched '].tolist()
# Out:
# True

# %%
matched_df1 = pd.merge(matched_df, rct_matched)

# %%
matched_df1.shape
# Out:
# (1226, 18)

# %%
matched_df.to_csv("Matched_metadata.csv")

# %%
matched_df1.to_csv("Matched_metadata1.csv")

# %%
matched_group = pd.read_csv("Matched_metadata.csv")

# %%
matched_group.head()
# Out:
#              Study ID      Study Name  \
# 0  STD-Litkowski-2005  Litkowski 2005
# 1    STD-Chapman-2002    Chapman 2002
# 2    STD-Lazarus-2001    Lazarus 2001
# 3        STD-EACG-017        EACG 017
# 4    STD-Winston-1993    Winston 1993
#
#                                                Title Alternative Title  \
# 0  Analgesic efficacy and tolerability of oxycodo...              None
# 1  The addition of salmeterol 50 mcg bid to antic...              None
# 2  Long-acting ß2-agonist monotherapy versus cont...              None
# 3  Zidovudine twice daily in asymptomatic subject...              None
# 4  Fluconazole prophylaxis of fungal infections i...              None
#
#                                              Authors             Type  \
# 0  Litkowski LJ, Christensen SE, Adamson DN, Van ...  JOURNAL_ARTICLE
# 1  Chapman K, Arvidsson P, Chuchalin A, Dhillon D...  JOURNAL_ARTICLE
# 2  Lazarus SC, Boushey H, Fahy JV, Chinchilli VM,...  JOURNAL_ARTICLE
# 3  Mulder JW, Cooper DA, Mathiesen L, Sandstrom E...  JOURNAL_ARTICLE
# 4  Winston DJ, Chandrasekar PH, Lazarus HM, Goodm...  JOURNAL_ARTICLE
#
#   Reference ID  ID Matched  Reference ID Type Reference ID Other Type  \
# 0      2736006     15922815             OTHER                  CRSREF
# 1         None     12068339              None                    None
# 2         None     11368732              None                    None
# 3         None      7913326              None                    None
# 4      3405798      8442620             OTHER                  CRSREF
#
#                              Published Journal  Year Volume     Page  \
# 0                        Clinical Therapeutics  2005     27   418-29
# 1                 Canadian Respiratory Journal  2002      9   178-85
# 2  Journal of the American Medical Association  2001    285  2583-93
# 3                                         AIDS  1994      8  313-321
# 4                  Annals of Internal Medicine  1993    118  495-503
#
#                                      Cochrane Review  year  citation-only  \
# 0  CD002763 v. 11.0 Single dose oral oxycodone an...  2005        0.99998
# 1  CD001104 v. 7.0 Long-acting beta2-agonists for...  2002        0.99988
# 2  CD001385 v. 9.0 Long-acting beta2-agonists for...  2001        0.99992
# 3  CD002039 v. 5.0 Immediate versus deferred zido...  1994        0.99960
# 4  CD000026 v. 16.0 Routine versus selective anti...  1993        0.99991
#
#    citation-plus-mesh
# 0             0.99997
# 1             0.99995
# 2             0.99992
# 3             0.99992
# 4             0.99991

# %%
unmatched_df.to_csv("unmatched_group.csv")

# %%
matched_group2 = matched_group[matched_group['citation-plus-mesh'] > 0.01]

# %%
matched_group2.to_csv("matched_group2.csv")

# %%
matched_group3 = matched_group[matched_group['citation-plus-mesh'] <= 0.01]

# %%
matched_group3.to_csv("matched_group3.csv")

# %%
df1 = df[['Cochrane Review', 'Study ID', 'ID Matched ']]

# %%
df1.head()
# Out:
#                                      Cochrane Review            Study ID  \
# 0  CD000026 v. 16.0 Routine versus selective anti...      STD-Acuna-1981
# 1  CD000026 v. 16.0 Routine versus selective anti...  STD-Benhamou-1991a
# 2  CD000026 v. 16.0 Routine versus selective anti...  STD-Benhamou-1991a
# 3  CD000026 v. 16.0 Routine versus selective anti...   STD-Brincker-1978
# 4  CD000026 v. 16.0 Routine versus selective anti...   STD-Brincker-1983
#
#                  ID Matched
# 0  NOT_FOUND;INVALID_JOURNAL
# 1                    2049556
# 2                  NOT_FOUND
# 3                     356523
# 4                    6308441

# %%
df1.shape
# Out:
# (1695, 3)

# %%
df1.shape[0]
# Out:
# 1695

# %%
df1.loc[1, 'ID Matched ']
# Out:
# 2049556

# %%
for i in range(df1.shape[0]):
    if type(df1.loc[i, "ID Matched "]) == int:
        df1.loc[i, "ID Matched "] = 'MATCHED'
    if "AMBIGUOUS" in df1.loc[i, "ID Matched "]:
        df1.loc[i, "ID Matched "] = 'AMBIGUOUS'
# Out:
# C:\Users\yoges\Anaconda3\lib\site-packages\pandas\core\indexing.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\yoges\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\yoges\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
df1.head()
# Out:
#                                      Cochrane Review            Study ID  \
# 0  CD000026 v. 16.0 Routine versus selective anti...      STD-Acuna-1981
# 1  CD000026 v. 16.0 Routine versus selective anti...  STD-Benhamou-1991a
# 2  CD000026 v. 16.0 Routine versus selective anti...  STD-Benhamou-1991a
# 3  CD000026 v. 16.0 Routine versus selective anti...   STD-Brincker-1978
# 4  CD000026 v. 16.0 Routine versus selective anti...   STD-Brincker-1983
#
#                  ID Matched
# 0  NOT_FOUND;INVALID_JOURNAL
# 1                    MATCHED
# 2                  NOT_FOUND
# 3                    MATCHED
# 4                    MATCHED

# %%
df1.shape
# Out:
# (1695, 3)

# %%
df1['ID Matched '].value_counts()
# Out:
# MATCHED                      1099
# NOT_FOUND;INVALID_JOURNAL     333
# NOT_FOUND                     259
# AMBIGUOUS                       4
# Name: ID Matched , dtype: int64

# %%
df2 = df1.groupby(['Cochrane Review', 'Study ID', 'ID Matched ']).size().reset_index()

# %%
df2.shape
# Out:
# (1287, 4)

# %%
df2.columns = ['Cochrane Review', 'Study ID', 'ID Matched','Count']

# %%
df3 = df2.pivot_table(index = ['Cochrane Review', 'Study ID'], columns = 'ID Matched', values = 'Count')

# %%
df3 = df3.fillna(0)

# %%
df3.head()
# Out:
# ID Matched                                                             AMBIGUOUS  \
# Cochrane Review                                    Study ID
# CD000026 v. 16.0 Routine versus selective antif... STD-Acuna-1981            0.0
#                                                    STD-Benhamou-1991a        0.0
#                                                    STD-Brincker-1978         0.0
#                                                    STD-Brincker-1983         0.0
#                                                    STD-Caselli-1990          0.0
#
# ID Matched                                                             MATCHED  \
# Cochrane Review                                    Study ID
# CD000026 v. 16.0 Routine versus selective antif... STD-Acuna-1981          0.0
#                                                    STD-Benhamou-1991a      1.0
#                                                    STD-Brincker-1978       1.0
#                                                    STD-Brincker-1983       1.0
#                                                    STD-Caselli-1990        1.0
#
# ID Matched                                                             NOT_FOUND  \
# Cochrane Review                                    Study ID
# CD000026 v. 16.0 Routine versus selective antif... STD-Acuna-1981            0.0
#                                                    STD-Benhamou-1991a        1.0
#                                                    STD-Brincker-1978         0.0
#                                                    STD-Brincker-1983         0.0
#                                                    STD-Caselli-1990          0.0
#
# ID Matched                                                             NOT_FOUND;INVALID_JOURNAL
# Cochrane Review                                    Study ID
# CD000026 v. 16.0 Routine versus selective antif... STD-Acuna-1981                            1.0
#                                                    STD-Benhamou-1991a                        0.0
#                                                    STD-Brincker-1978                         0.0
#                                                    STD-Brincker-1983                         0.0
#                                                    STD-Caselli-1990                          0.0

# %%
print("Total number of Ambiguous errros are:" ,df3['AMBIGUOUS'].sum())
print("Total number of Not_Found errros are:" ,df3['NOT_FOUND'].sum())
print("Total number of Invalid Journal errros are:" ,df3['NOT_FOUND;INVALID_JOURNAL'].sum())
print("Total number of Matched articles are:" ,df3['MATCHED'].sum())
# Out:
# Total number of Ambiguous errros are: 4
# Total number of Not_Found errros are: 259
# Total number of Invalid Journal errros are: 333
# Total number of Matched articles are: 1099

# %%
cols = ['AMBIGUOUS','NOT_FOUND','NOT_FOUND;INVALID_JOURNAL','MATCHED']
df3[cols] = df3[cols].applymap(np.int64)

# %%
df3.head()
# Out:
# ID Matched                                                             AMBIGUOUS  \
# Cochrane Review                                    Study ID
# CD000026 v. 16.0 Routine versus selective antif... STD-Acuna-1981              0
#                                                    STD-Benhamou-1991a          0
#                                                    STD-Brincker-1978           0
#                                                    STD-Brincker-1983           0
#                                                    STD-Caselli-1990            0
#
# ID Matched                                                             MATCHED  \
# Cochrane Review                                    Study ID
# CD000026 v. 16.0 Routine versus selective antif... STD-Acuna-1981            0
#                                                    STD-Benhamou-1991a        1
#                                                    STD-Brincker-1978         1
#                                                    STD-Brincker-1983         1
#                                                    STD-Caselli-1990          1
#
# ID Matched                                                             NOT_FOUND  \
# Cochrane Review                                    Study ID
# CD000026 v. 16.0 Routine versus selective antif... STD-Acuna-1981              0
#                                                    STD-Benhamou-1991a          1
#                                                    STD-Brincker-1978           0
#                                                    STD-Brincker-1983           0
#                                                    STD-Caselli-1990            0
#
# ID Matched                                                             NOT_FOUND;INVALID_JOURNAL
# Cochrane Review                                    Study ID
# CD000026 v. 16.0 Routine versus selective antif... STD-Acuna-1981                              1
#                                                    STD-Benhamou-1991a                          0
#                                                    STD-Brincker-1978                           0
#                                                    STD-Brincker-1983                           0
#                                                    STD-Caselli-1990                            0

# %%
df3.to_csv("Error Mapping.csv")
